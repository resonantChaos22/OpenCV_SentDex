# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import urllib.request
import os

# %%
def store_raw_images():
    neg_images_link = 'http://image-net.org/api/text/imagenet.synset.geturls?wnid=n00523513'
    neg_images_urls = urllib.request.urlopen(neg_images_link).read().decode()
    
    if not os.path.exists('neg'):
        os.makedirs('neg')
    n = 0    
    pic_num = 1    
    for i in neg_images_urls.split('/n'):
        try:
            print(i)
            
            urllib.request.urlretrieve(i, 'neg/{}.jpg'.format(str(pic_num)))
            img = cv2.imread('neg/{}.jpg'.format(str(pic_num)), 0)
            resized_img = cv2.resize(img, (100, 100)) 
            cv2.imwrite('neg/{}.jpg'.format(str(strpic_num)), resized_img)
            pic_num+=1
            

            
        except Exception as E:
            print(str(E))
            
        n+=1
        print('K'+str(n))

# %%
store_raw_images()
# Out:
# http://www.landon.net/uploaded/top_banner_photos/AthleticsTemp.jpg
# http://www.nait.ca/athletics/images/mbasketball_main.JPG
# http://www.eindhovensesportraad.nl/UserFiles/Image/atletiek%20DSC_6707web.JPG
# http://extras.mnginteractive.com/live/media/site571/2009/0312/20090312__ecct0313athletics~1_Viewer.JPG
# http://www.hsc.edu/athletics/football/images/simpson_act.jpg
# http://www.canton.edu/athletics/m_lacrosse/images/kolb(act).jpg
# http://s7ondemand1.scene7.com/is/image/roadrunnersports/PRO105?wid=323&hei=238
# http://www.act.edu
# <html>
#
# K1
# ews_images/20060105115450275.jpg
# http://static.flickr.com/3199/3024707873_320c34433a.jpg
# http://harbor.laccd.omniupdate.com/athletics/womenssoccer/teampic0607.jpg
# http://www.bcferries.com/files/community/images/Athletics220.gif
# http://www.dgs.edu.hk/chin/pics/athletics_finals19.jpg
# http://www.minuteman.org/athletics/images/tj_act.jpg
# http://images.theage.com.au/ftage/ffximage/2008/12/19/majshoe_narrowweb__300x440,0.jpg
# ...

# %%
def store_raw_images():
    neg_images_link = 'http://image-net.org/api/text/imagenet.synset.geturls?wnid=n00523513'   
    neg_image_urls = urllib.request.urlopen(neg_images_link).read().decode()
    pic_num = 1
    n=0
    
    if not os.path.exists('neg'):
        os.makedirs('neg')
        
    for i in neg_image_urls.split('\n'):
        try:
            print(i)
            print(pic_num)
            urllib.request.urlretrieve(i, "neg/"+str(pic_num)+".jpg")
            img = cv2.imread("neg/"+str(pic_num)+".jpg",cv2.IMREAD_GRAYSCALE)
            # should be larger than samples / pos pic (so we can place our image on it)
            resized_image = cv2.resize(img, (100, 100))
            cv2.imwrite("neg/"+str(pic_num)+".jpg",resized_image)
            pic_num += 1
            
            
            
        except Exception as e:
            print(str(e))  
        n+=1    
        print(n)

# %%
store_raw_images()
# Out:
# http://www.landon.net/uploaded/top_banner_photos/AthleticsTemp.jpg
# 1
# HTTP Error 403: Forbidden
# 1
# http://www.nait.ca/athletics/images/mbasketball_main.JPG
# 1
# HTTP Error 404: Not Found
# 2
# http://www.eindhovensesportraad.nl/UserFiles/Image/atletiek%20DSC_6707web.JPG
# 1
# HTTP Error 404: Not Found
# 3
# http://extras.mnginteractive.com/live/media/site571/2009/0312/20090312__ecct0313athletics~1_Viewer.JPG
# 1
# HTTP Error 404: Not Found
# 4
# http://www.hsc.edu/athletics/football/images/simpson_act.jpg
# 1
# HTTP Error 404: Not Found
# 5
# http://www.canton.edu/athletics/m_lacrosse/images/kolb(act).jpg
# 1
# HTTP Error 404: Not Found
# 6
# http://s7ondemand1.scene7.com/is/image/roadrunnersports/PRO105?wid=323&hei=238
# 1
# 7
# http://www.act.edu/news_images/20060105115450275.jpg
# 2
# OpenCV(4.1.0) ../modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# 8
# http://static.flickr.com/3199/3024707873_320c34433a.jpg
# 2
# ...

# %%
"neg/"+str(1)+".jpg"=='neg/{}.jpg'.format(str(1))
# Out:
# True
